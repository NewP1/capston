# %%
import os
import math
import random

###########################################################################
# 당신의 데이터 셋 비율을 조정합니다.
# 세 변수의 합이 100이 되도록 해주세요.
train_set_ratio = 80
validation_set_ratio = 20
test_set_ratio = 0
############################################################################

# file_path는 조정해주세요. 현 상태는 data/SplitDatAsTXT.py가 있고, data/images 안에 이미지들이 있습니다.
file_path = r'D:\version_6\punch_name/'
# 역슬래쉬가 아닌 /로 구분하기 위해 변경해줍니다.

file_names = os.listdir(file_path)
file_len = len(file_names)
i=0
while i<file_len:
    temp_fileName = file_names[i]
    if temp_fileName[-4:] == ".txt":
        file_names.pop(i)
        file_len = len(file_names)
        #print(str(i) + "   " + str(file_len) + "    " + temp_fileName)
    else: i += 1
        
while len(file_names) > 0:
    if len(file_names) == math.ceil(file_len * (validation_set_ratio / 100)):
        print('----------------------------test set----------------------------')
        for file_name in file_names:
            print('data/images/' + file_name)
        break
    else:
        file = file_names.pop(random.randint(0, len(file_names) - 1))
        print('data/images/' + file)
    
    

# # 1. Test Set 목록
# print("****************** 1. Train Set 목록(비율: " + str(train_set_ratio) + "%) ******************")
# for i in range(0, math.ceil(file_len * (train_set_ratio / 100))):
    
#     print('data/images/' + file_names[i])
# final_index = math.ceil(file_len * (train_set_ratio / 100))

# # 2. Validation Set 목록
# print("****************** 2. Validation Set 목록(비율: " + str(validation_set_ratio) + "%) ******************")
# for i in range(final_index, final_index+ math.ceil(file_len * (validation_set_ratio / 100))):
#     print('data/images/' + file_names[i])
# final_index = final_index + math.ceil(file_len * (validation_set_ratio / 100))

# 3. Test Set 목록
# print("****************** 3. Test Set 목록(비율: " + str(test_set_ratio) + "%) ******************")
# for i in range(final_index, file_len):
#     print('data/images/' + file_names[i])
# Out:
# data/images/punch__64.png
# data/images/punch__131.png
# data/images/punch__110.png
# data/images/punch__205.png
# data/images/punch__19.png
# data/images/punch__17.png
# data/images/punch__130.png
# data/images/punch__164.png
# data/images/punch__177.png
# data/images/punch__194.png
# data/images/punch__44.png
# data/images/punch__197.png
# data/images/punch__37.png
# data/images/punch__27.png
# data/images/punch__35.png
# data/images/punch__137.png
# data/images/punch__59.png
# data/images/punch__140.png
# data/images/punch__118.png
# data/images/punch__186.png
# data/images/punch__169.png
# data/images/punch__182.png
# data/images/punch__96.png
# data/images/punch__165.png
# data/images/punch__39.png
# data/images/punch__180.png
# data/images/punch__150.png
# data/images/punch__84.png
# data/images/punch__153.png
# data/images/punch__91.png
# data/images/punch__89.png
# data/images/punch__202.png
# data/images/punch__10.png
# data/images/punch__189.png
# data/images/punch__41.png
# data/images/punch__20.png
# data/images/punch__6.png
# data/images/punch__104.png
# data/images/punch__14.png
# data/images/punch__95.png
# data/images/punch__103.png
# data/images/punch__156.png
# data/images/punch__57.png
# data/images/punch__82.png
# data/images/punch__61.png
# data/images/punch__22.png
# data/images/punch__34.png
# data/images/punch__179.png
# data/images/punch__18.png
# data/images/punch__46.png
# data/images/punch__190.png
# data/images/punch__65.png
# data/images/punch__166.png
# data/images/punch__159.png
# data/images/punch__26.png
# data/images/punch__45.png
# data/images/punch__149.png
# data/images/punch__192.png
# data/images/punch__146.png
# data/images/punch__51.png
# data/images/punch__88.png
# data/images/punch__199.png
# data/images/punch__114.png
# data/images/punch__53.png
# data/images/punch__100.png
# data/images/punch__145.png
# data/images/punch__86.png
