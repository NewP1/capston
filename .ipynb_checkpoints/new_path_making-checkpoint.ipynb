# %%
import os
import math
import random

###########################################################################
# 당신의 데이터 셋 비율을 조정합니다.
# 세 변수의 합이 100이 되도록 해주세요.
train_set_ratio = 80
validation_set_ratio = 20
test_set_ratio = 0
############################################################################

# file_path는 조정해주세요. 현 상태는 data/SplitDatAsTXT.py가 있고, data/images 안에 이미지들이 있습니다.
file_path = r'C:\Users\jaehy\OneDrive\바탕 화면\d.v2i.darknet\train\images\punch/'
# 역슬래쉬가 아닌 /로 구분하기 위해 변경해줍니다.

file_names = os.listdir(file_path)
file_len = len(file_names)
i=0
while i<file_len:
    temp_fileName = file_names[i]
    if temp_fileName[-4:] == ".txt":
        file_names.pop(i)
        file_len = len(file_names)
        #print(str(i) + "   " + str(file_len) + "    " + temp_fileName)
    else: i += 1
        
while len(file_names) > 0:
    if len(file_names) == math.ceil(file_len * (validation_set_ratio / 100)):
        print('----------------------------test set----------------------------')
        for file_name in file_names:
            print('data/images/' + file_name)
        break
    else:
        file = file_names.pop(random.randint(0, len(file_names) - 1))
        print('data/images/' + file)
    
    

# # 1. Test Set 목록
# print("****************** 1. Train Set 목록(비율: " + str(train_set_ratio) + "%) ******************")
# for i in range(0, math.ceil(file_len * (train_set_ratio / 100))):
    
#     print('data/images/' + file_names[i])
# final_index = math.ceil(file_len * (train_set_ratio / 100))

# # 2. Validation Set 목록
# print("****************** 2. Validation Set 목록(비율: " + str(validation_set_ratio) + "%) ******************")
# for i in range(final_index, final_index+ math.ceil(file_len * (validation_set_ratio / 100))):
#     print('data/images/' + file_names[i])
# final_index = final_index + math.ceil(file_len * (validation_set_ratio / 100))

# 3. Test Set 목록
# print("****************** 3. Test Set 목록(비율: " + str(test_set_ratio) + "%) ******************")
# for i in range(final_index, file_len):
#     print('data/images/' + file_names[i])
# Out:
# data/images/punch_18.png
# data/images/punch_55.png
# data/images/punch_11.png
# data/images/punch_0.png
# data/images/punch_45.png
# data/images/punch_152.png
# data/images/punch_115.png
# data/images/punch_125.png
# data/images/punch_64.png
# data/images/punch_66.png
# data/images/punch_83.png
# data/images/punch_183.png
# data/images/punch_127.png
# data/images/punch_44.png
# data/images/punch_174.png
# data/images/punch_39.png
# data/images/punch_61.png
# data/images/punch_135.png
# data/images/punch_118.png
# data/images/punch_54.png
# data/images/punch_97.png
# data/images/punch_187.png
# data/images/punch_6.png
# data/images/punch_21.png
# data/images/punch_139.png
# data/images/punch_121.png
# data/images/punch_103.png
# data/images/punch_177.png
# data/images/punch_72.png
# data/images/punch_182.png
# data/images/punch_87.png
# data/images/punch_116.png
# data/images/punch_124.png
# data/images/punch_15.png
# data/images/punch_84.png
# data/images/punch_35.png
# data/images/punch_181.png
# data/images/punch_67.png
# data/images/punch_99.png
# data/images/punch_59.png
# data/images/punch_81.png
# data/images/punch_29.png
# data/images/punch_78.png
# data/images/punch_168.png
# data/images/punch_155.png
# data/images/punch_109.png
# data/images/punch_42.png
# data/images/punch_52.png
# data/images/punch_49.png
# data/images/punch_89.png
# data/images/punch_170.png
# data/images/punch_120.png
# data/images/punch_140.png
# data/images/punch_153.png
# data/images/punch_137.png
# data/images/punch_172.png
# data/images/punch_180.png
