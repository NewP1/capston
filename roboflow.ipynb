# %%
from glob import glob
import cv2
import os
from PIL import Image, ImageEnhance, ImageChops
import numpy as np
import time
from tqdm import tqdm
import shutil

# %%
path = r'C:\Users\jaehy\OneDrive\바탕 화면\d.v2i.darknet\train/'

#fall 0
#kick 1
#punch 2

# %%
file_list = glob(path + '*.txt')
classtxt = path[:-1] + '\classes.txt'
# print(classtxt)
if classtxt in file_list:
    file_list.remove(classtxt)
arr = [0] * 5
cnt = 0

print(file_list)
# Out:
# ['C:\\Users\\jaehy\\OneDrive\\바탕 화면\\d.v2i.darknet\\train\\falldown_0_png.rf.26cc4a1ae5f88c4429bc830532373cbe.txt', 'C:\\Users\\jaehy\\OneDrive\\바탕 화면\\d.v2i.darknet\\train\\falldown_100_png.rf.144bf7db9d13a62d7c679375313dbbd7.txt', 'C:\\Users\\jaehy\\OneDrive\\바탕 화면\\d.v2i.darknet\\train\\falldown_101_png.rf.0a197e8e62ed0e5736f7654a39e4a8d9.txt', 'C:\\Users\\jaehy\\OneDrive\\바탕 화면\\d.v2i.darknet\\train\\falldown_102_png.rf.5cb7ded364f0b2a1d0ae10e4cfb27fb3.txt', 'C:\\Users\\jaehy\\OneDrive\\바탕 화면\\d.v2i.darknet\\train\\falldown_103_png.rf.cf2f11d416048cca75ca13fc641f053a.txt', 'C:\\Users\\jaehy\\OneDrive\\바탕 화면\\d.v2i.darknet\\train\\falldown_104_png.rf.ab00bce7aa6b6bf79277d92ada23c70f.txt', 'C:\\Users\\jaehy\\OneDrive\\바탕 화면\\d.v2i.darknet\\train\\falldown_105_png.rf.e26a8080f2d8834cb501bb0bd7a9e0d9.txt', 'C:\\Users\\jaehy\\OneDrive\\바탕 화면\\d.v2i.darknet\\train\\falldown_106_png.rf.0b0c9e8cd1a2ea7902e3d57fc2cd00ac.txt', 'C:\\Users\\jaehy\\OneDrive\\바탕 화면\\d.v2i.darknet\\train\\falldown_107_png.rf.5be3a8030a0f93113ed94f6fdf88354c.txt', 'C:\\Users\\jaehy\\OneDrive\\바탕 화면\\d.v2i.darknet\\train\\falldown_108_png.rf.e2c684190820eb7162badcb4135abea7.txt', 'C:\\Users\\jaehy\\OneDrive\\바탕 화면\\d.v2i.darknet\\train\\falldown_109_png.rf.4a61641f27d675f487131287b35d77d1.txt', 'C:\\Users\\jaehy\\OneDrive\\바탕 화면\\d.v2i.darknet\\train\\falldown_10_png.rf.51c8b57846c9ca71e3f529d4ec791d19.txt', 'C:\\Users\\jaehy\\OneDrive\\바탕 화면\\d.v2i.darknet\\train\\falldown_110_png.rf.6efe1ddfcdf782f6b37e32eb88b8cd5c.txt', 'C:\\Users\\jaehy\\OneDrive\\바탕 화면\\d.v2i.darknet\\train\\falldown_111_png.rf.92224538219435d87d5b633a14c9fc8a.txt', 'C:\\Users\\jaehy\\OneDrive\\바탕 화면\\d.v2i.darknet\\train\\falldown_112_png.rf.ab793d96f31c35e4be5df9884f2549a9.txt', 'C:\\Users\\jaehy\\OneDrive\\바탕 화면\\d.v2i.darknet\\train\\falldown_113_png.rf.a55ebdfcbc4b4a28ae1381593c71fdaa.txt', 'C:\\Users\\jaehy\\OneDrive\\바탕 화면\\d.v2i.darknet\\train\\falldown_114_png.rf.2beeab7b58fcd1b0708539a794af74f8.txt', 'C:\\Users\\jaehy\\OneDrive\\바탕 화면\\d.v2i.darknet\\train\\falldown_115_png.rf.5260100de3281c8cccb48305b5a7691f.txt', 'C:\\Users\\jaehy\\OneDrive\\바탕 화면\\d.v2i.darknet\\train\\falldown_116_png.rf.363d19553e7c9da92cd57e1f37e4d111.txt', 'C:\\Users\\jaehy\\OneDrive\\바탕 화면\\d.v2i.darknet\\train\\falldown_117_png.rf.0eaf23adf687bd775dbb4616565d7009.txt', 'C:\\Users\\jaehy\\OneDrive\\바탕 화면\\d.v2i.darknet\\train\\falldown_118_png.rf.813362e80018b6450d13d269ced60ec1.txt', 'C:\\Users\\jaehy\\OneDrive\\바탕 화면\\d.v2i.darknet\\train\\falldown_119_png.rf.50cfd2fc86de90db81cfc01476985ed5.txt', 'C:\\Users\\jaehy\\OneDrive\\바탕 화면\\d.v2i.darknet\\train\\falldown_11_png.rf.ae61a978da5b178728c246e6b808b184.txt', 'C:\\Users\\jaehy\\OneDrive\\바탕 화면\\d.v2i.darknet\\train\\falldown_120_png.rf.489cd39298bcf4c1379568b5393ef96c.txt', 'C:\\Users\\jaehy\\OneDrive\\바탕 화면\\d.v2i.darknet\\train\\falldown_121_png.rf.a469331e5952d8a1b9a484d8342403fc.txt', 'C:\\Users\\jaehy\\OneDrive\\바탕 화면\\d.v2i.darknet\\train\\falldown_122_png.rf.4d958e0d5615559da3ed65229485e70f.txt', 'C:\\Users\\jaehy\\OneDrive\\바탕 화면\\d.v2i.darknet\\train\\falldown_123_png.rf.332385b8070c3190b77ed083f57d0d1f.txt', 'C:\\Users\\jaehy\\OneDrive\\바탕 화면\\d.v2i.darknet\\train\\falldown_124_png.rf.d89b3f31f16f5f4987b2e0d8000057c0.txt', 'C:\\Users\\jaehy\\OneDrive\\바탕 화면\\d.v2i.darknet\\train\\falldown_125_png.rf.5d804730fc925669faba418a74b771f3.txt', 'C:\\Users\\jaehy\\OneDrive\\바탕 화면\\d.v2i.darknet\\train\\falldown_126_png.rf.d3a066e04683dc5358190006038f345a.txt', 'C:\\Users\\jaehy\\OneDrive\\바탕 화면\\d.v2i.darknet\\train\\falldown_127_png.rf.b739593180b202de05b8dee96c6a5049.txt', 'C:\\Users\\jaehy\\OneDrive\\바탕 화면\\d.v2i.darknet\\train\\falldown_128_png.rf.1363d243726a745e3a3b322fa572d4ed.txt', 'C:\\Users\\jaehy\\OneDrive\\바탕 화면\\d.v2i.darknet\\train\\falldown_129_png.rf.e223ff380dbaa8955dd37219390d6bea.txt', 'C:\\Users\\jaehy\\OneDrive\\바탕 화면\\d.v2i.darknet\\train\\falldown_12_png.rf.3915480296caa388f03c1295e143e876.txt', 'C:\\Users\\jaehy\\OneDriv ...

# %% [markdown]
# # fall, kick, punch

# %%
for file in file_list:
    with open(file, 'r') as f:
        lines = f.readlines()
    with open(file, 'w') as f:
        for line in lines:
            tmp = list(line.split())
            index = int(tmp[0])
            if index == 0:
                tmp[0] = '4'
                f.write(' '.join(tmp)+'\n')
            elif index == 1:
                tmp[0] = '3'
                f.write(' '.join(tmp) + '\n')
            elif index == 2:
                tmp[0] = '2'
                f.write(' '.join(tmp) + '\n')
            else:
                f.write(' '.join(tmp) + '\n')

# %% [markdown]
# # V_NV

# %%
# for file in file_list:
#     with open(file, 'r') as f:
#         lines = f.readlines()
#     with open(file, 'w') as f:
#         for line in lines:
#             tmp = list(line.split())
#             index = int(tmp[0])
#             if index == 0:
#                 tmp[0] = '2'
#                 f.write(' '.join(tmp)+'\n')
#             else :
#                 f.write(line)

# %%
for file in file_list:
    with open(file, 'r') as f:
        lines = f.readlines()
    with open(file, 'w') as f:
        for line in lines:
            tmp = list(line.split())
            index = int(tmp[0])
            if index == 0:
                tmp[0] = '2'
                f.write(' '.join(tmp)+'\n')
