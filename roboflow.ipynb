# %%
from glob import glob
import cv2
import os
from PIL import Image, ImageEnhance, ImageChops
import numpy as np
import time
from tqdm import tqdm
import shutil

# %%
path = r'D:\version_6\roboflow_f_k_p\punch.v4i.darknet\train/'

#fall 0
#kick 1
#punch 2

# %%
file_list = glob(path + '*.txt')
classtxt = path[:-1] + '\classes.txt'
# print(classtxt)
if classtxt in file_list:
    file_list.remove(classtxt)
arr = [0] * 5
cnt = 0

print(file_list)
# Out:
# ['D:\\version_6\\roboflow_f_k_p\\punch.v4i.darknet\\train\\20230321_172531_010_saved_h_png.rf.43c398945d0819643ce1ba6bd06ba898.txt', 'D:\\version_6\\roboflow_f_k_p\\punch.v4i.darknet\\train\\20230321_172531_010_saved_h_png.rf.540a33b356d154d3809fbac8aedf4e0c.txt', 'D:\\version_6\\roboflow_f_k_p\\punch.v4i.darknet\\train\\20230321_172531_010_saved_h_png.rf.7101673da65a9065b3f046bd93b1921a.txt', 'D:\\version_6\\roboflow_f_k_p\\punch.v4i.darknet\\train\\20230321_172531_010_saved_png.rf.0340f5fa406adc9ef5d2e89d775b9897.txt', 'D:\\version_6\\roboflow_f_k_p\\punch.v4i.darknet\\train\\20230321_172531_010_saved_png.rf.7ce6081d729a934ea5e788bf1a213d74.txt', 'D:\\version_6\\roboflow_f_k_p\\punch.v4i.darknet\\train\\20230321_172531_010_saved_png.rf.c3fb4f48ed28e64bae345fba15ac87d5.txt', 'D:\\version_6\\roboflow_f_k_p\\punch.v4i.darknet\\train\\20230321_172531_018_saved_h_png.rf.13f8ff8ef802739740f13a74b8c8396b.txt', 'D:\\version_6\\roboflow_f_k_p\\punch.v4i.darknet\\train\\20230321_172531_018_saved_h_png.rf.28c7ef23194ab7abcbba0e6b44cd62fb.txt', 'D:\\version_6\\roboflow_f_k_p\\punch.v4i.darknet\\train\\20230321_172531_018_saved_h_png.rf.7803db35bdc127b6aadf3ee467138da8.txt', 'D:\\version_6\\roboflow_f_k_p\\punch.v4i.darknet\\train\\20230321_172531_018_saved_png.rf.15bfede7a3d0ae40ee3255d440a948e8.txt', 'D:\\version_6\\roboflow_f_k_p\\punch.v4i.darknet\\train\\20230321_172531_018_saved_png.rf.2cc325e7b311a073bc8477427c0e21ba.txt', 'D:\\version_6\\roboflow_f_k_p\\punch.v4i.darknet\\train\\20230321_172531_018_saved_png.rf.8ec49b66aeeb8c3414700af8514318cf.txt', 'D:\\version_6\\roboflow_f_k_p\\punch.v4i.darknet\\train\\20230321_172551_018_saved_h_png.rf.1db8615ee7a30775cd6c9d12662b0d27.txt', 'D:\\version_6\\roboflow_f_k_p\\punch.v4i.darknet\\train\\20230321_172551_018_saved_h_png.rf.76c0b12ac897132211d571fcaa015b0a.txt', 'D:\\version_6\\roboflow_f_k_p\\punch.v4i.darknet\\train\\20230321_172551_018_saved_h_png.rf.c29c77c9ce5ac28cf6e9a888b735bfc0.txt', 'D:\\version_6\\roboflow_f_k_p\\punch.v4i.darknet\\train\\20230321_172551_018_saved_png.rf.20fb138a10aa8cdfca88083cea83ab5f.txt', 'D:\\version_6\\roboflow_f_k_p\\punch.v4i.darknet\\train\\20230321_172551_018_saved_png.rf.309173fd0e60d23e8d0e6cb85e234c08.txt', 'D:\\version_6\\roboflow_f_k_p\\punch.v4i.darknet\\train\\20230321_172551_018_saved_png.rf.ec37d6aa583f129773010f5848750dac.txt', 'D:\\version_6\\roboflow_f_k_p\\punch.v4i.darknet\\train\\20230321_172551_034_saved_h_png.rf.6506f0eea00f5d332d9108e1ee73e22d.txt', 'D:\\version_6\\roboflow_f_k_p\\punch.v4i.darknet\\train\\20230321_172551_034_saved_h_png.rf.d287333f1ed1436fc5a3f50ea981efff.txt', 'D:\\version_6\\roboflow_f_k_p\\punch.v4i.darknet\\train\\20230321_172551_034_saved_h_png.rf.fd8f9cb6ee5ec0bfb84aa12c57de4cb1.txt', 'D:\\version_6\\roboflow_f_k_p\\punch.v4i.darknet\\train\\20230321_172551_034_saved_png.rf.22fb34772291a0395738854aa2d73848.txt', 'D:\\version_6\\roboflow_f_k_p\\punch.v4i.darknet\\train\\20230321_172551_034_saved_png.rf.78788c175c30fe181634b58c03b454a3.txt', 'D:\\version_6\\roboflow_f_k_p\\punch.v4i.darknet\\train\\20230321_172551_034_saved_png.rf.b5af54ef8c37f416a19161c3b361e78c.txt', 'D:\\version_6\\roboflow_f_k_p\\punch.v4i.darknet\\train\\20230321_172609_014_saved_h_png.rf.e972f18c6204ff70fe5b07bb3fd33de3.txt', 'D:\\version_6\\roboflow_f_k_p\\punch.v4i.darknet\\train\\20230321_172609_014_saved_h_png.rf.eba84336645c4312fa12d8f1cca9ad68.txt', 'D:\\version_6\\roboflow_f_k_p\\punch.v4i.darknet\\train\\20230321_172609_014_saved_h_png.rf.f3451458761f550d8f21a080070adceb.txt', 'D:\\version_6\\roboflow_f_k_p\\punch.v4i.darknet\\train\\20230321_172609_014_saved_png.rf.b949efab38543e762bccb13efab2d2e7.txt', 'D:\\version_6\\roboflow_f_k_p\\punch.v4i.darknet\\train\\20230321_172609_014_saved_png.rf.e3a042828e7a48f2a7ab3e1787c332b9.txt', 'D:\\version_6\\roboflow_f_k_p\\punch.v4i.darknet\\train\\20230321_172609_014_saved_png.rf.e9666e0c9baf35125332d6eca15d7db1.txt', 'D:\\version_6\\roboflow_f_k_p\\punch.v4i.darknet\\train\\20230321_17 ...

# %% [markdown]
# # fall, kick, punch

# %%
# for file in file_list:
#     with open(file, 'r') as f:
#         lines = f.readlines()
#     with open(file, 'w') as f:
#         for line in lines:
#             tmp = list(line.split())
#             index = int(tmp[0])
#             if index == 0:
#                 tmp[0] = '4'
#                 f.write(' '.join(tmp)+'\n')
#             elif index == 1:
#                 tmp[0] = '3'
#                 f.write(' '.join(tmp) + '\n')
#             elif index == 2:
#                 tmp[0] = '2'
#                 f.write(' '.join(tmp) + '\n')
#             else:
#                 f.write(' '.join(tmp) + '\n')

# %% [markdown]
# # V_NV

# %%
# for file in file_list:
#     with open(file, 'r') as f:
#         lines = f.readlines()
#     with open(file, 'w') as f:
#         for line in lines:
#             tmp = list(line.split())
#             index = int(tmp[0])
#             if index == 0:
#                 tmp[0] = '2'
#                 f.write(' '.join(tmp)+'\n')
#             else :
#                 f.write(line)

# %%
for file in file_list:
    with open(file, 'r') as f:
        lines = f.readlines()
    with open(file, 'w') as f:
        for line in lines:
            tmp = list(line.split())
            index = int(tmp[0])
            if index == 0:
                tmp[0] = '2'
                f.write(' '.join(tmp)+'\n')
