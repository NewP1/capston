# %%
from glob import glob
import os
path = r'D:\4\images/'

file_list = glob(path + '*.txt')
# print(file_list)
for file in file_list:
    print(file)
    os.remove(file)
# Out:
# D:\4\images\classes.txt
# D:\4\images\kick_croki_11_0_frame5.txt
# D:\4\images\kick_croki_11_1_frame14.txt
# D:\4\images\kick_croki_11_1_frame15.txt
# D:\4\images\kick_croki_1_8_frame2.txt
# D:\4\images\kick_croki_2_0_frame32.txt
# D:\4\images\kick_croki_3_5_frame5.txt
# D:\4\images\kick_croki_6_5_frame69.txt
# D:\4\images\kick_outside_100_0_frame0.txt
# D:\4\images\kick_outside_100_0_frame12.txt
# D:\4\images\kick_outside_100_0_frame13.txt
# D:\4\images\kick_outside_100_0_frame16.txt
# D:\4\images\kick_outside_100_0_frame17.txt
# D:\4\images\kick_outside_100_0_frame18.txt
# D:\4\images\kick_outside_100_0_frame2.txt
# D:\4\images\kick_outside_100_0_frame21.txt
# D:\4\images\kick_outside_100_0_frame22.txt
# D:\4\images\kick_outside_100_0_frame24.txt
# D:\4\images\kick_outside_100_0_frame25.txt
# D:\4\images\kick_outside_100_0_frame26.txt
# D:\4\images\kick_outside_100_0_frame29.txt
# D:\4\images\kick_outside_100_0_frame3.txt
# D:\4\images\kick_outside_100_0_frame30.txt
# ...
