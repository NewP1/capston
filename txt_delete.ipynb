# %%
from glob import glob
import os
path = r'D:\4\punch/'

file_list = glob(path + '*.txt')
# print(file_list)
for file in file_list:
    print(file)
    os.remove(file)
# Out:
# D:\4\punch\1_frame0.txt
# D:\4\punch\1_frame100.txt
# D:\4\punch\1_frame105.txt
# D:\4\punch\1_frame107.txt
# D:\4\punch\1_frame111.txt
# D:\4\punch\1_frame116.txt
# D:\4\punch\1_frame127.txt
# D:\4\punch\1_frame133.txt
# D:\4\punch\1_frame25.txt
# D:\4\punch\1_frame34.txt
# D:\4\punch\1_frame60.txt
# D:\4\punch\classes.txt
# D:\4\punch\kick_croki_1_7_frame7.txt
# D:\4\punch\kick_outside_2_1_frame50.txt
# D:\4\punch\kick_outside_2_1_frame51.txt
# D:\4\punch\kick_outside_2_1_frame54.txt
# D:\4\punch\kick_outside_2_1_frame55.txt
# D:\4\punch\kick_outside_2_1_frame62.txt
# D:\4\punch\kick_outside_2_1_frame63.txt
# D:\4\punch\kick_outside_2_1_frame74.txt
# D:\4\punch\kick_outside_2_1_frame75.txt
# D:\4\punch\kick_outside_2_1_frame76.txt
# D:\4\punch\kick_outside_64_2_frame22.txt
# D:\4\punch\kick_outside_95_0_frame123.txt
# D:\4\punch\kick_outside_95_0_frame124.txt
# D:\4\punch\pull_outside_10_0_frame5.txt
# D:\4\punch\pull_outside_10_0_frame6.txt
# ...
